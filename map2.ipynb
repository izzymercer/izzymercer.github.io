# %% [markdown]
# <a href="https://colab.research.google.com/github/izzymercer/izzymercer.github.io/blob/main/map2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests, pandas as pd

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_average_yearly_temperature')

# %%
df = pd.read_json('temp.json')

# %%
print(df)
# Out:
# [              Country Average yearly temperature (1961–1990 Celsius)
# 0        Burkina Faso                                          28.29
# 1                Mali                                          28.25
# 2            Kiribati                                          28.20
# 3            Djibouti                                          28.00
# 4            Maldives                                          28.00
# ..                ...                                            ...
# 187   Norway [note 1]                                          01.50
# 188           Iceland                                          −0.70
# 189  Denmark [note 2]                                          −3.70
# 190            Canada                                          −5.10
# 191            Russia                                          −5.35
#
# [192 rows x 2 columns]]

# %%
countries_to_keep = ['Western Sahara','Egypt', 'Equatorial Guinea', 'Eritrea', 'Libya', 'Morocco', 'Mauritania', 'Somalia', 'Democratic Republic of the Congo', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Tunisia', 'Western Sahara', 'Gabon',  'Eswatini', 'Algeria', 'Comoros', 'Democratic Republic of the Congo', 'Cameroon', 'Angola', 'Benin', 'Burundi', 'Ghana','Liberia', 'Mozambique', 'Sierra Leone', 'South Sudan', 'Togo', 'Uganda', 'Zambia',  'Senegal', 'Ethiopia', 'Lesotho', 'Mali', 'Zimbabwe', 'Namibia', 'Central African Republic', 'Eswatini', 'Gambia',  'Guinea', 'Madagascar', 'Nigeria', 'Botswana', 'Chad', 'Cabo Verde', 'Kenya', 'Mauritius', 'Malawi', 'Rwanda']

mask = df['country'].isin(countries_to_keep)

filtered_df = df[mask]

print(filtered_df)
# Out:
#                               country  yearly-average-temp
# 2                             Algeria                22.50
# 4                              Angola                21.55
# 18                              Benin                27.55
# 22                           Botswana                21.50
# 27                            Burundi                19.80
# 29                           Cameroon                24.60
# 32           Central African Republic                24.90
# 33                               Chad                26.55
# 37                            Comoros                25.55
# 38   Democratic Republic of the Congo                24.00
# 51                              Egypt                22.10
# 53                  Equatorial Guinea                24.55
# 54                            Eritrea                25.50
# 56                           Ethiopia                22.20
# 60                              Gabon                25.05
# ...

# %%
filtered_df
# Out:
#                               country  yearly-average-temp
# 2                             Algeria                22.50
# 4                              Angola                21.55
# 18                              Benin                27.55
# 22                           Botswana                21.50
# 27                            Burundi                19.80
# 29                           Cameroon                24.60
# 32           Central African Republic                24.90
# 33                               Chad                26.55
# 37                            Comoros                25.55
# 38   Democratic Republic of the Congo                24.00
# 51                              Egypt                22.10
# 53                  Equatorial Guinea                24.55
# 54                            Eritrea                25.50
# 56                           Ethiopia                22.20
# 60                              Gabon                25.05
# ...

# %%
exported_values = list(filtered_df.T.to_dict().values() )

# %%
open('temp_data2.json', 'w').write( json.dumps(exported_values))
# Out:
# 2294
