# %% [markdown]
# <a href="https://colab.research.google.com/github/izzymercer/izzymercer.github.io/blob/main/chart6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('chart4_data.csv')

# %%
print(df)
# Out:
#                  Country Name         AG        GDP pc  population   \
# 0                      Angola   7.882625   6881.076241     32353588
# 1                       Benin  26.875802   3289.655169     12290444
# 2                    Botswana   2.087164  15756.043780      2499702
# 3                Burkina Faso  18.376103   2199.116626     20951639
# 4                     Burundi  28.844390    760.453399     11874838
# ..                        ...        ...           ...          ...
# 99   Turks and Caicos Islands   0.360360  27028.024420        43080
# 100      United Arab Emirates   0.746712  74811.690220      9211657
# 101            United Kingdom   0.604508  49041.463550     66836327
# 102             United States   0.838813  65094.799430    328329953
# 103                   Uruguay   6.452670  24238.133050      3428409
#
#             Income Group                      Region
# 0    Lower middle income          Sub-Saharan Africa
# ...

# %%
import math

# Create a new column for the log of GDP per capita

df["log_GDP_pc"] = df["GDP pc"].apply(math.log10)

# Preview the DataFrame
df.head()
# Out:
#    Country Name         AG        GDP pc  population          Income Group  \
# 0        Angola   7.882625   6881.076241     32353588  Lower middle income
# 1         Benin  26.875802   3289.655169     12290444  Lower middle income
# 2      Botswana   2.087164  15756.043780      2499702  Upper middle income
# 3  Burkina Faso  18.376103   2199.116626     20951639           Low income
# 4       Burundi  28.844390    760.453399     11874838           Low income
#
#                Region  log_GDP_pc
# 0  Sub-Saharan Africa    3.837656
# 1  Sub-Saharan Africa    3.517150
# 2  Sub-Saharan Africa    4.197447
# 3  Sub-Saharan Africa    3.342248
# 4  Sub-Saharan Africa    2.881073

# %%
df1 = df.drop(['GDP pc'], axis=1)

# %%
df1.to_csv('log.csv')

# %%
exported_values = list(df.T.to_dict().values())

# %%
df.T.to_dict().values()
# Out:
# dict_values([{'Country Name': 'Angola', 'AG': 7.882624763, 'GDP pc': 6881.076241, 'population ': 32353588, 'Income Group': 'Lower middle income', 'Region': 'Sub-Saharan Africa', 'log_GDP_pc': 3.837656369772299}, {'Country Name': 'Benin', 'AG': 26.87580163, 'GDP pc': 3289.655169, 'population ': 12290444, 'Income Group': 'Lower middle income', 'Region': 'Sub-Saharan Africa', 'log_GDP_pc': 3.517150376354456}, {'Country Name': 'Botswana', 'AG': 2.087164114, 'GDP pc': 15756.04378, 'population ': 2499702, 'Income Group': 'Upper middle income', 'Region': 'Sub-Saharan Africa', 'log_GDP_pc': 4.197447178876505}, {'Country Name': 'Burkina Faso', 'AG': 18.37610291, 'GDP pc': 2199.116626, 'population ': 20951639, 'Income Group': 'Low income', 'Region': 'Sub-Saharan Africa', 'log_GDP_pc': 3.342248261959771}, {'Country Name': 'Burundi', 'AG': 28.84439, 'GDP pc': 760.4533989, 'population ': 11874838, 'Income Group': 'Low income', 'Region': 'Sub-Saharan Africa', 'log_GDP_pc': 2.881072605344066}, {'Co
# ...

# %%
exported_values
# Out:
# [{'Country Name': 'Angola',
#   'AG': 7.882624763,
#   'GDP pc': 6881.076241,
#   'population ': 32353588,
#   'Income Group': 'Lower middle income',
#   'Region': 'Sub-Saharan Africa',
#   'log_GDP_pc': 3.837656369772299},
#  {'Country Name': 'Benin',
#   'AG': 26.87580163,
#   'GDP pc': 3289.655169,
#   'population ': 12290444,
#   'Income Group': 'Lower middle income',
#   'Region': 'Sub-Saharan Africa',
#   'log_GDP_pc': 3.517150376354456},
#  {'Country Name': 'Botswana',
#   'AG': 2.087164114,
#   'GDP pc': 15756.04378,
#   'population ': 2499702,
#   'Income Group': 'Upper middle income',
#   'Region': 'Sub-Saharan Africa',
#   'log_GDP_pc': 4.197447178876505},
#  {'Country Name': 'Burkina Faso',
#   'AG': 18.37610291,
#   'GDP pc': 2199.116626,
#   'population ': 20951639,
#   'Income Group': 'Low income',
#   'Region': 'Sub-Saharan Africa',
#   'log_GDP_pc': 3.342248261959771},
#  {'Country Name': 'Burundi',
#   'AG': 28.84439,
#   'GDP pc': 760.4533989,
# ...

# %%
import json

# %%
json.dumps(exported_values)
# Out:
# '[{"Country Name": "Angola", "AG": 7.882624763, "GDP pc": 6881.076241, "population ": 32353588, "Income Group": "Lower middle income", "Region": "Sub-Saharan Africa", "log_GDP_pc": 3.837656369772299}, {"Country Name": "Benin", "AG": 26.87580163, "GDP pc": 3289.655169, "population ": 12290444, "Income Group": "Lower middle income", "Region": "Sub-Saharan Africa", "log_GDP_pc": 3.517150376354456}, {"Country Name": "Botswana", "AG": 2.087164114, "GDP pc": 15756.04378, "population ": 2499702, "Income Group": "Upper middle income", "Region": "Sub-Saharan Africa", "log_GDP_pc": 4.197447178876505}, {"Country Name": "Burkina Faso", "AG": 18.37610291, "GDP pc": 2199.116626, "population ": 20951639, "Income Group": "Low income", "Region": "Sub-Saharan Africa", "log_GDP_pc": 3.342248261959771}, {"Country Name": "Burundi", "AG": 28.84439, "GDP pc": 760.4533989, "population ": 11874838, "Income Group": "Low income", "Region": "Sub-Saharan Africa", "log_GDP_pc": 2.881072605344066}, {"Country Name"
# ...

# %%
open('chart4_data1.json','w').write(json.dumps(exported_values))
# Out:
# 20486

# %%
#regression of GDP per capita on share of agriclture as GDP 
#JSON file - include the continet and country and total GDP and population.

# %%
#exported_values = list(df.T.to_dict().values())
#df.T.to_dict().values()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
from google.colab import files
files.download("log.csv")

# %%
import seaborn as sns
sns.set()

# %%
sns.regplot(x='log_GDP_pc',y='AG',data=df1)

# %%
from scipy.stats import linregress

# %%
slope, intercept, rvalue, pvalue, stderr = linregress(x=df1['log_GDP_pc'], y=df1['AG'])

# %%
print('y = ',np.round(slope,2),' * x + ',np.round(intercept,2))
print('R² = ',np.round(rvalue**2,2))
# Out:
# y =  -16.85  * x +  79.84
# R² =  0.72
